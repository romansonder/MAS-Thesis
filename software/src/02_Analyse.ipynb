# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../data/Prep_81346-2_Objects.csv')
df.shape
# Out:
# (3164, 8)

# %%
df.head()
# Out:
#   EK   UK  UUK Kennzeichen                                  Klassendefinition  \
# 0  B  NaN  NaN           B  Objekt zur Erfassung und Darstellung von Infor...
# 1  B  NaN  NaN           B  Objekt zur Erfassung und Darstellung von Infor...
# 2  B   BA  NaN          BA        Erkennungsobjekt für elektrisches Potential
# 3  B   BA  NaN          BA        Erkennungsobjekt für elektrisches Potential
# 4  B   BA  BAA         BAA  Objekt zur Erkennung von elektrischem Potentia...
#
#                                        Klassenname  \
# 0                                 Erkennungsobjekt
# 1                                 Erkennungsobjekt
# 2  Objekt zur Erkennung von elektrischem Potential
# 3  Objekt zur Erkennung von elektrischem Potential
# 4                                 Spannungswandler
#
#                          Beispiele  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# ...

# %%
df.describe()
# Out:
#           EK    UK   UUK Kennzeichen  \
# count   3164  3113  2798        3162
# unique    17   165   615         797
# top        B    UL   KEC         KEC
# freq     556   152    30          30
#
#                                         Klassendefinition  \
# count                                                3164
# unique                                                796
# top     Elektrisches Signalverarbeitungsobjekt zur Ein...
# freq                                                   30
#
#                 Klassenname        Beispiele  \
# count                  3164             2208
# unique                  794              664
# top     Kommunikationsgerät  Präsenzdetektor
# freq                     30               15
#
#                                                    Target
# count                                                3164
# unique                                               2241
# top     Elektrisches Signalverarbeitungsobjekt zur Ein...
# ...

# %%
sns.histplot(df['EK'])
# Out:
# <Axes: xlabel='EK', ylabel='Count'>

# %%
sns.histplot(df['UK'])
# Out:
# <Axes: xlabel='UK', ylabel='Count'>

# %%
sns.histplot(df['UUK'])
# Out:
# <Axes: xlabel='UUK', ylabel='Count'>

# %%
df.EK.value_counts()
# Out:
# B    556
# U    432
# X    203
# F    196
# E    188
# T    179
# H    178
# W    165
# R    159
# G    142
# P    130
# Q    130
# N    129
# K    118
# C     89
# S     86
# M     84
# Name: EK, dtype: int64

# %%
df.UK.value_counts()
# Out:
# UL    152
# BG    107
# KE     77
# BQ     65
# UB     64
#      ...
# CF      4
# CC      4
# CB      4
# CA      4
# XZ      4
# Name: UK, Length: 165, dtype: int64

# %%
df.UK.value_counts().describe()
# Out:
# count    165.000000
# mean      18.866667
# std       18.076239
# min        4.000000
# 25%        8.000000
# 50%       13.000000
# 75%       24.000000
# max      152.000000
# Name: UK, dtype: float64

# %%
df.UK.value_counts()[df.UK.value_counts() < 5].sum()
# Out:
# 44

# %%
df[df.UK == "CB"]
# Out:
#     EK  UK  UUK Kennzeichen  \
# 562  C  CB  NaN          CB
# 563  C  CB  NaN          CB
# 564  C  CB  CBA         CBA
# 565  C  CB  CBA         CBA
#
#                                      Klassendefinition  \
# 562  Speicherobjekt für elektrische Energie innerha...
# 563  Speicherobjekt für elektrische Energie innerha...
# 564     Induktives Speicherobjekt für induktive Ladung
# 565     Induktives Speicherobjekt für induktive Ladung
#
#                    Klassenname Beispiele  \
# 562  Induktives Speicherobjekt       NaN
# 563  Induktives Speicherobjekt       NaN
# 564               Drosselspule       NaN
# 565               Drosselspule       NaN
#
#                                                 Target
# 562  Speicherobjekt für elektrische Energie innerha...
# 563                          Induktives Speicherobjekt
# 564                                       Drosselspule
# 565     Induktives Speicherobjekt für induktive Ladung

# %%
df.UUK.value_counts()
# Out:
# KEC    30
# EAA    27
# UCA    27
# ULK    24
# BGE    21
#        ..
# RAC     2
# GBB     2
# RAA     2
# QZA     2
# XZA     2
# Name: UUK, Length: 615, dtype: int64
